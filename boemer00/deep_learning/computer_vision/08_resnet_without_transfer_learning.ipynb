# %% [markdown]
# <a href="https://colab.research.google.com/github/boemer00/deep_learning/blob/main/boemer00/deep_learning/computer_vision/08_resnet_without_transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries

# %%
try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# 2.15.0

# %%
# standard libraries
from glob import glob

# third-party libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import (Activation, Add, BatchNormalization, Conv2D, Dense,
                          Flatten, Input, Lambda, MaxPooling2D, ZeroPadding2D,
                          add)
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Prep

# %%
# config
IMAGE_SIZE = [224, 224]
epochs = 16
batch_size = 128

# %%
# !wget -nc https://archive.org/download/blood_cell_images/blood_cell_images.zip
# Out:
# --2023-12-21 13:48:49--  https://archive.org/download/blood_cell_images/blood_cell_images.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia801204.us.archive.org/14/items/blood_cell_images/blood_cell_images.zip [following]
# --2023-12-21 13:48:49--  https://ia801204.us.archive.org/14/items/blood_cell_images/blood_cell_images.zip
# Resolving ia801204.us.archive.org (ia801204.us.archive.org)... 207.241.228.24
# Connecting to ia801204.us.archive.org (ia801204.us.archive.org)|207.241.228.24|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 109834540 (105M) [application/zip]
# Saving to: ‘blood_cell_images.zip’
#
# blood_cell_images.z 100%[===================>] 104.75M  21.2MB/s    in 4.1s
#
# 2023-12-21 13:48:53 (25.8 MB/s) - ‘blood_cell_images.zip’ saved [109834540/109834540]

# %%
# !unzip -nq blood_cell_images.zip

# %%
# !ls
# Out:
# blood_cell_images  blood_cell_images.zip  __MACOSX  sample_data

# %%
# https://www.kaggle.com/paultimothymooney/blood-cells
train_path = 'blood_cell_images/TRAIN'
valid_path = 'blood_cell_images/TEST'

# %%
# file details ('/class/img_name.jp*g')
train_images = glob(train_path + '/*/*.jp*g')
valid_images = glob(valid_path + '/*/*.jp*g')

# %%
# path to get the number of classes
folders = glob(train_path + '/*')

# %%
# check an image
plt.imshow(image.load_img(np.random.choice(train_images)))
plt.show()

# %% [markdown]
# # Build Model

# %%
def conv_block(input_, kernel_size, filters, strides=(2, 2)):
  f1, f2, f3 = filters

  x = Conv2D(f1, (1, 1), strides=strides, kernel_initializer='he_normal')(input_)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(f2, kernel_size, padding='same', kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(f3, (1, 1), kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)

  shortcut = Conv2D(f3, (1, 1), strides=strides, kernel_initializer='he_normal')(input_)
  shortcut = BatchNormalization()(shortcut)

  x = add([x, shortcut])
  x = Activation('relu')(x)

  return x

# %%
def identity_block(input_, kernel_size, filters):
  f1, f2, f3 = filters

  x = Conv2D(f1, (1, 1), kernel_initializer='he_normal')(input_)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(f2, kernel_size, padding='same', kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)
  x = Activation('relu')(x)

  x = Conv2D(f3, (1, 1), kernel_initializer='he_normal')(x)
  x = BatchNormalization()(x)

  x = add([x, input_])
  x = Activation('relu')(x)

  return x

# %% [markdown]
# In the code above, `f1` and `(1, 1)` represent different aspects of the convolutional layer defined by Conv2D:
#
# - **f1**: this represents the number of filters in the convolutional layer. Each filter is essentially a small matrix that is convolved with the input data. The number of filters, `f1`, determines the depth of the output feature map. So, if `f1` is `64`, for instance, your convolutional layer will have `64` distinct filters, each learning to recognize different features from the input, resulting in an output feature map with a depth of `64`.
#
# - **(1, 1)**: this represents the size of the kernel used in each filter. A kernel size of `(1, 1)` means that each filter has a 1x1 window. It scans through the input data one pixel at a time. In convolutional neural networks, different kernel sizes can be used to capture various spatial features. A 1x1 convolution, as used here, is typically for altering the depth of the feature map (such as increasing or reducing the number of channels) without affecting its spatial dimensions (height and width).
#
# - **strides**: This parameter defines the step size that each filter takes as it moves across the input data. If strides is set to (2, 2), for example, the filter skips one pixel both horizontally and vertically between applications. This results in downsampling the spatial dimensions of the output feature map by a factor of 2 in both height and width.
#
# **In summary**:
#
# - `f1` is the number of distinct 1x1 filters applied to the input.
# - `(1, 1)` is the size of each of these filters.
# - `strides` determine how these filters stride across the input data, affecting the size of the output feature map.

# %%
# custom resnet
i = Input(shape=IMAGE_SIZE + [3])
x = ZeroPadding2D(padding=(3, 3))(i)
x = Conv2D(64, (7, 7), strides=(2, 2), padding='valid', kernel_initializer='he_normal')(x)

x = BatchNormalization()(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D((3, 3), strides=(2, 2))(x)

x = conv_block(x, 3, [64, 64, 256], strides=(1, 1))
x = identity_block(x, 3, [64, 64, 256])
x = identity_block(x, 3, [64, 64, 256])

x = conv_block(x, 3, [128, 128, 512])
x = identity_block(x, 3, [128, 128, 512])
x = identity_block(x, 3, [128, 128, 512])
x = identity_block(x, 3, [128, 128, 512])

# %%
# bespoke layers
x = Flatten()(x)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(len(folders), activation='softmax')(x)

# %%
# create the model object
model = Model(inputs=i, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  zero_padding2d_4 (ZeroPadd  (None, 230, 230, 3)          0         ['input_3[0][0]']
#  ing2D)
#
#  conv2d_48 (Conv2D)          (None, 112, 112, 64)         9472      ['zero_padding2d_4[0][0]']
#
#  batch_normalization_48 (Ba  (None, 112, 112, 64)         256       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 112, 112, 64)         0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  zero_padding2d_5 (ZeroPadd  (None, 114, 114, 64)         0         ['activation_44[0][0]']
#  ing2D)
#
#  max_pooling2d_2 (MaxPoolin  (None, 56, 56, 64)           0         ['zero_padding2d_5[0][0]']
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 56, 56, 64)           4160      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_49 (Ba  (None, 56, 56, 64)           256       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_50 (Conv2D)          (None, 56, 56, 64)           36928     ['activation_45[0][0]']
#
#  batch_normalization_50 (Ba  (None, 56, 56, 64)           256       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 56, 56, 256)          16640     ['activation_46[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 56, 56, 256)          16640     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_51 (Ba  (None, 56, 56, 256)          1024      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 56, 56, 256)          1024      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_51[0][0]
#                                                                     ',
#                                                                      'batch_normalization_52[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 56, 56, 256)          0         ['add_14[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 56, 56, 64)           16448     ['activation_47[0][0]']
#
#  batch_normalization_53 (Ba  (None, 56, 56, 64)           256       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_54 (Conv2D)          (None, 56, 56, 64)           36928     ['activation_48[0][0]']
#
#  batch_normalization_54 (Ba  (None, 56, 56, 64)           256       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 56, 56, 256)          16640     ['activation_49[0][0]']
#
#  batch_normalization_55 (Ba  (None, 56, 56, 256)          1024      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_55[0][0]
#                                                                     ',
#                                                                      'activation_47[0][0]']
#
#  activation_50 (Activation)  (None, 56, 56, 256)          0         ['add_15[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 56, 56, 64)           16448     ['activation_50[0][0]']
#
#  batch_normalization_56 (Ba  (None, 56, 56, 64)           256       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 56, 56, 64)           36928     ['activation_51[0][0]']
#
#  batch_normalization_57 (Ba  (None, 56, 56, 64)           256       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 56, 56, 64)           0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 256)          16640     ['activation_52[0][0]']
#
#  batch_normalization_58 (Ba  (None, 56, 56, 256)          1024      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_58[0][0]
#                                                                     ',
#                                                                      'activation_50[0][0]']
#
#  activation_53 (Activation)  (None, 56, 56, 256)          0         ['add_16[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 28, 28, 128)          32896     ['activation_53[0][0]']
#
#  batch_normalization_59 (Ba  (None, 28, 28, 128)          512       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_54[0][0]']
#
#  batch_normalization_60 (Ba  (None, 28, 28, 128)          512       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  conv2d_61 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_55[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 28, 28, 512)          131584    ['activation_53[0][0]']
#
#  batch_normalization_61 (Ba  (None, 28, 28, 512)          2048      ['conv2d_61[0][0]']
#  tchNormalization)
#
#  batch_normalization_62 (Ba  (None, 28, 28, 512)          2048      ['conv2d_62[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_61[0][0]
#                                                                     ',
#                                                                      'batch_normalization_62[0][0]
#                                                                     ']
#
#  activation_56 (Activation)  (None, 28, 28, 512)          0         ['add_17[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_56[0][0]']
#
#  batch_normalization_63 (Ba  (None, 28, 28, 128)          512       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  activation_57 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  conv2d_64 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_57[0][0]']
#
#  batch_normalization_64 (Ba  (None, 28, 28, 128)          512       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  activation_58 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_58[0][0]']
#
#  batch_normalization_65 (Ba  (None, 28, 28, 512)          2048      ['conv2d_65[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_65[0][0]
#                                                                     ',
#                                                                      'activation_56[0][0]']
#
#  activation_59 (Activation)  (None, 28, 28, 512)          0         ['add_18[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_59[0][0]']
#
#  batch_normalization_66 (Ba  (None, 28, 28, 128)          512       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  activation_60 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_67 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_60[0][0]']
#
#  batch_normalization_67 (Ba  (None, 28, 28, 128)          512       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  activation_61 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  conv2d_68 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_61[0][0]']
#
#  batch_normalization_68 (Ba  (None, 28, 28, 512)          2048      ['conv2d_68[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_68[0][0]
#                                                                     ',
#                                                                      'activation_59[0][0]']
#
#  activation_62 (Activation)  (None, 28, 28, 512)          0         ['add_19[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 128)          65664     ['activation_62[0][0]']
#
#  batch_normalization_69 (Ba  (None, 28, 28, 128)          512       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_63 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 28, 28, 128)          147584    ['activation_63[0][0]']
#
#  batch_normalization_70 (Ba  (None, 28, 28, 128)          512       ['conv2d_70[0][0]']
#  tchNormalization)
#
#  activation_64 (Activation)  (None, 28, 28, 128)          0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_71 (Conv2D)          (None, 28, 28, 512)          66048     ['activation_64[0][0]']
#
#  batch_normalization_71 (Ba  (None, 28, 28, 512)          2048      ['conv2d_71[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_71[0][0]
#                                                                     ',
#                                                                      'activation_62[0][0]']
#
#  activation_65 (Activation)  (None, 28, 28, 512)          0         ['add_20[0][0]']
#
#  flatten_2 (Flatten)         (None, 401408)               0         ['activation_65[0][0]']
#
#  dense_3 (Dense)             (None, 4)                    1605636   ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 3065732 (11.69 MB)
# Trainable params: 3055620 (11.66 MB)
# Non-trainable params: 10112 (39.50 KB)
# __________________________________________________________________________________________________

# %%
# inform methods
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=['accuracy']
    )

# %%
# create an instance of ImageDataGenerator
train_gen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=lambda x: (x / 127.5) - 1
)

val_gen = ImageDataGenerator(
    preprocessing_function=lambda x: (x / 127.5) - 1
)

# %% [markdown]
# - `x /= 127.5`: This line scales the pixel values of the image. Normally, image pixel values range from 0 to 255 (for 8-bit images). Dividing by 127.5 transforms these values to a range of 0 to 2. This is a common preprocessing step in image processing, especially for neural network models, as it normalizes the data.
#
# - `x -= 1.`: After the division, this line shifts the range from 0-2 to -1 to 1. This means the pixel values of the image will now range from -1 to 1. Centering the data around zero can help improve the performance of the model by ensuring that the input feature distribution is centered and symmetric.

# %%
# get label mapping for confusion matrix plot later
test_gen = val_gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE, class_mode='sparse')
print(test_gen.class_indices)

labels = [None] * len(test_gen.class_indices)
for k, v in test_gen.class_indices.items():
  labels[v] = k
# Out:
# Found 2487 images belonging to 4 classes.
# {'EOSINOPHIL': 0, 'LYMPHOCYTE': 1, 'MONOCYTE': 2, 'NEUTROPHIL': 3}

# %%
# should be NOT a strangely coloured image
for x, y in test_gen:
  print('min: ', x[0].min(), 'max: ', x[0].max())
  plt.title(labels[np.argmax(y[0])])
  plt.imshow(x[0])
  plt.show()
  break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# min:  -1.0 max:  1.0

# %%
# create generators
train_generator = train_gen.flow_from_directory(
  train_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
  class_mode='sparse',
)
valid_generator = val_gen.flow_from_directory(
  valid_path,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
  class_mode='sparse',
)
# Out:
# Found 9957 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.

# %% [markdown]
# # Train Model

# %%
checkpoint_filepath = '/tmp/checkpoint'

# calculate steps
steps_per_epoch = len(train_images) // batch_size
validation_steps = len(valid_images) // batch_size

# define callbacks
callbacks = [
    EarlyStopping(
        monitor='loss',
        patience=3,
        restore_best_weights=True
    ),
    ModelCheckpoint(
        filepath=checkpoint_filepath,
        save_weights_only=True,
        monitor='val_accuracy',
        mode='max',
        save_best_only=True
    ),
]

# fit the model
r = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=epochs,
    steps_per_epoch=steps_per_epoch,
    validation_steps=validation_steps,
    callbacks=callbacks
)
# Out:
# Epoch 1/16
# 77/77 [==============================] - 207s 2s/step - loss: 43.7541 - accuracy: 0.3081 - val_loss: 9.8949 - val_accuracy: 0.2521
# Epoch 2/16
# 77/77 [==============================] - 158s 2s/step - loss: 2.2762 - accuracy: 0.5553 - val_loss: 11.4618 - val_accuracy: 0.2755
# Epoch 3/16
# 77/77 [==============================] - 154s 2s/step - loss: 1.3660 - accuracy: 0.7431 - val_loss: 2.2403 - val_accuracy: 0.5181
# Epoch 4/16
# 77/77 [==============================] - 155s 2s/step - loss: 0.9173 - accuracy: 0.8208 - val_loss: 2.6441 - val_accuracy: 0.6505
# Epoch 5/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.6781 - accuracy: 0.8423 - val_loss: 2.2746 - val_accuracy: 0.7373
# Epoch 6/16
# 77/77 [==============================] - 155s 2s/step - loss: 0.3025 - accuracy: 0.9116 - val_loss: 1.2213 - val_accuracy: 0.8211
# Epoch 7/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.2802 - accuracy: 0.9165 - val_loss: 4.9812 - val_accuracy: 0.5201
# Epoch 8/16
# 77/77 [==============================] - 155s 2s/step - loss: 0.1946 - accuracy: 0.9390 - val_loss: 1.4274 - val_accuracy: 0.6982
# Epoch 9/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.1249 - accuracy: 0.9568 - val_loss: 1.1845 - val_accuracy: 0.8018
# Epoch 10/16
# 77/77 [==============================] - 155s 2s/step - loss: 0.1104 - accuracy: 0.9603 - val_loss: 1.1597 - val_accuracy: 0.8248
# Epoch 11/16
# 77/77 [==============================] - 151s 2s/step - loss: 0.0996 - accuracy: 0.9662 - val_loss: 2.3797 - val_accuracy: 0.7508
# Epoch 12/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.1014 - accuracy: 0.9665 - val_loss: 0.6897 - val_accuracy: 0.8306
# Epoch 13/16
# 77/77 [==============================] - 149s 2s/step - loss: 0.0860 - accuracy: 0.9705 - val_loss: 1.0852 - val_accuracy: 0.7858
# Epoch 14/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.1187 - accuracy: 0.9609 - val_loss: 1.9784 - val_accuracy: 0.8104
# Epoch 15/16
# 77/77 [==============================] - 150s 2s/step - loss: 0.0634 - accuracy: 0.9777 - val_loss: 4.0900 - val_accuracy: 0.6410
# Epoch 16/16
# 77/77 [==============================] - 154s 2s/step - loss: 0.0631 - accuracy: 0.9788 - val_loss: 1.6970 - val_accuracy: 0.7574

# %% [markdown]
# # Evaluate Model

# %%
def plot_history(history):
    metrics = list(history.keys())
    num_metrics = len(metrics) // 2
    plt.figure(figsize=(6 * num_metrics, 5))

    for i, metric in enumerate(metrics[:num_metrics]):
        plt.subplot(1, num_metrics, i + 1)
        plt.plot(history[metric], label=f'Training {metric.capitalize()}')
        plt.plot(history[f'val_{metric}'], label=f'Validation {metric.capitalize()}')
        plt.title(f'Training and Validation {metric.capitalize()}')
        plt.xlabel('Epoch')
        plt.ylabel(metric.capitalize())
        plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(r.history)

# %%
model.load_weights(checkpoint_filepath)

# %%
def get_confusion_matrix(data_path):
    print("Generating confusion matrix")
    all_predictions = []
    all_targets = []

    for batch_data, batch_labels in val_gen.flow_from_directory(data_path, target_size=IMAGE_SIZE, shuffle=False, batch_size=batch_size):
        predictions = model.predict(batch_data)
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = np.argmax(batch_labels, axis=1)

        all_predictions.append(predicted_classes)
        all_targets.append(true_classes)

    all_predictions = np.concatenate(all_predictions)
    all_targets = np.concatenate(all_targets)

    cm = confusion_matrix(all_targets, all_predictions)
    return cm

# %%
# cm = get_confusion_matrix(train_path)
# print(cm)

# %%
# valid_cm = get_confusion_matrix(valid_path)
# print(valid_cm)

# %%
import itertools

def plot_confusion_matrix(cm, class_labels, normalize=False,
                          title='Confusion matrix', cmap=plt.cm.Blues):
    """
    Plots a confusion matrix.
    Args:
        cm (numpy.ndarray): Confusion matrix to be plotted.
        class_labels (list): List of class labels.
        normalize (bool): Normalize the confusion matrix.
        title (str): Title of the plot.
        cmap (matplotlib.colors.Colormap): Colormap to be used.
    """
    if not cm.any():
        print('Empty Confusion Matrix')
        return

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(class_labels))
    plt.xticks(tick_marks, class_labels, rotation=45)
    plt.yticks(tick_marks, class_labels)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment='center',
                 color='white' if cm[i, j] > thresh else 'black')

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
plot_confusion_matrix(cm, labels, title='Train confusion matrix')

# %%
np.trace(cm) / cm.sum()

# %%
np.trace(valid_cm) / valid_cm.sum()
